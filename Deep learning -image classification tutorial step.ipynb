# %%
import tensorflow as tf

# %%
import numpy as np

# %%
filename = 'C:/ProgramData/Anaconda3/image _data/1mage1.jpg'

# %%
from IPython.display import Image

# %%
Image(filename,width= 224, height = 224)

# %%
from tensorflow.keras.preprocessing import Image
Img = Image.load_Img(filename,target_size = (224,224))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-e669d2915413> in <module>
# ----> 1 from tensorflow.keras.preprocessing import Image
#       2 Img = Image.load_Img(filename,target_size = (224,224))
#
# ImportError: cannot import name 'Image' from 'tensorflow.keras.preprocessing' (C:\ProgramData\Anaconda3\lib\site-packages\keras\api\_v2\keras\preprocessing\__init__.py)

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size =(224,224))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
import cv2

# %%
imgg = cv2.imread(filename)

# %%
plt.imshow(imgg)

# %%
imgg = cv2.resize(imgg, (224,224))

# %%
plt.imshow(imgg)

# %%
plt.imshow(cv2.cvtcoolor(imgg, cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-22af8216ee3b> in <module>
# ----> 1 plt.imshow(cv2.cvtcoolor(imgg, cv2.COLOR_BGR2RGB))
#
# AttributeError: module 'cv2.cv2' has no attribute 'cvtcoolor'

# %%
plt.imshow(cv2.cvtColor(imgg, cv2.COLOR_BGR2RGB))

# %%
from PIL import Image

# %%
im = Image.open(filename)

# %%
im = im.resize((224,224))

# %%
plt.imshow(im)

# %%
mobile = tf.keras.applications.mobilenet_v3.MobileNet()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-3d8e2d30ca91> in <module>
# ----> 1 mobile = tf.keras.applications.mobilenet_v3.MobileNet()
#
# AttributeError: module 'keras.api._v2.keras.applications.mobilenet_v3' has no attribute 'MobileNet'

# %%
mobile = tf.keras.applications.mobilenet_v3.MobileNet_v3()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-3d7f79d1b122> in <module>
# ----> 1 mobile = tf.keras.applications.mobilenet_v3.MobileNet_v3()
#
# AttributeError: module 'keras.api._v2.keras.applications.mobilenet_v3' has no attribute 'MobileNet_v3'

# %%
mobile = tf.keras.applications.mobilenet_v2.MobileNet_v2()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-68683f128dd2> in <module>
# ----> 1 mobile = tf.keras.applications.mobilenet_v2.MobileNet_v2()
#
# AttributeError: module 'keras.api._v2.keras.applications.mobilenet_v2' has no attribute 'MobileNet_v2'

# %%
mobile = tf.keras.applications.mobilenet.MobileNet()
# Out:
# ...
# 17235968/17225924 [==============================] - 1s 0us/step

# %%
plt.imshow(img)

# %%
from tensorflow.keras.preprocessing import Image
Img = Image.load_Img(filename,target_size = (224,224))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-29-e669d2915413> in <module>
# ----> 1 from tensorflow.keras.preprocessing import Image
#       2 Img = Image.load_Img(filename,target_size = (224,224))
#
# ImportError: cannot import name 'Image' from 'tensorflow.keras.preprocessing' (C:\ProgramData\Anaconda3\lib\site-packages\keras\api\_v2\keras\preprocessing\__init__.py)

# %%
from tensorflow.keras.preprocessing import image
Img = image.load_Img(filename,target_size = (224,224))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-d71dc1fc75e3> in <module>
#       1 from tensorflow.keras.preprocessing import image
# ----> 2 Img = image.load_Img(filename,target_size = (224,224))
#
# AttributeError: module 'keras.api._v2.keras.preprocessing.image' has no attribute 'load_Img'

# %%
from tensorflow.keras.preprocessing import Image
img = Image.load_img(filename,target_size = (224,224))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-31-0c64c56bfef3> in <module>
# ----> 1 from tensorflow.keras.preprocessing import Image
#       2 img = Image.load_img(filename,target_size = (224,224))
#
# ImportError: cannot import name 'Image' from 'tensorflow.keras.preprocessing' (C:\ProgramData\Anaconda3\lib\site-packages\keras\api\_v2\keras\preprocessing\__init__.py)

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename,target_size = (224,224))

# %%
resize_img = image.img_to_array(img)
final_img =np.expand_dims(resize_img, axis = 0)
final_img = tf.keras.applications.mobilenet.preprocess_input(final_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-90598c25e491> in <module>
#       1 resize_img = image.img_to_array(img)
#       2 final_img =np.expand_dims(resize_img, axis = 0)
# ----> 3 final_img = tf.keras.applications.mobilenet.preprocess_input(final_image)
#
# NameError: name 'final_image' is not defined

# %%
resize_img = image.img_to_array(img)
final_img =np.expand_dims(resize_img, axis = 0)
final_img = tf.keras.applications.mobilenet.preprocess_input(final_img)

# %%
resize_img.shape
# Out:
# (224, 224, 3)

# %%
final_img.shape
# Out:
# (1, 224, 224, 3)

# %%
plt.imshow(final_img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-202b5e565771> in <module>
# ----> 1 plt.imshow(final_img)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2722         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2723         data=None, **kwargs):
# -> 2724     __ret = gca().imshow(
#    2725         X, cmap=cmap, norm=norm, aspect=aspect,
#    2726         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
# ...

# %%
predictions =  mobile.predict(final_img)

# %%
print(predictions)
# Out:
# [[5.84140762e-05 4.13823136e-06 3.86843294e-06 1.84836631e-06
#   6.10277993e-07 3.18156566e-07 1.77500112e-07 3.65326713e-07
#   1.37774009e-06 4.85146529e-07 1.04142578e-06 7.71832038e-06
#   7.35509843e-07 4.47911907e-06 1.48572678e-06 1.54434724e-06
#   7.60821251e-07 3.13836540e-06 1.78989274e-06 7.54141354e-07
#   2.06425443e-06 1.93526898e-06 1.72084285e-07 2.63835517e-07
#   3.63159842e-07 1.53370454e-08 2.69630345e-08 2.11616424e-07
#   9.00990642e-08 1.13170290e-06 8.91058605e-08 4.36611259e-07
#   6.26139780e-08 3.91441699e-06 2.04774024e-05 1.95372400e-06
#   1.03293267e-07 1.00745910e-06 2.76543688e-07 6.95992594e-06
#   2.06118762e-06 6.77475143e-08 3.08755013e-08 2.02075398e-06
#   1.72635282e-07 7.50060849e-07 1.44534727e-06 3.29448284e-07
#   9.39649226e-07 5.93901426e-08 3.20230598e-08 1.83348311e-05
#   2.77344981e-07 6.48920135e-08 3.62530227e-06 4.04790944e-06
#   8.53772377e-08 4.85798211e-08 1.18260914e-06 2.50516723e-06
# ...

# %%
    from tensorflow.keras.applications import imagenet_utils

# %%
results = imagenet_utils.decode_predictions(predictions)
# Out:
# ...
# 49152/35363 [=========================================] - 0s 0us/step

# %%
print(results)
# Out:
# [[('n03792972', 'mountain_tent', 0.56559664), ('n03782006', 'monitor', 0.12261972), ('n04152593', 'screen', 0.09892541), ('n03691459', 'loudspeaker', 0.027003068), ('n04258138', 'solar_dish', 0.012718906)]]
